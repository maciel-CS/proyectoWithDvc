# %%
# -*- coding: utf-8 -*-
import os, json, gc
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/proyectofin/Dataset_GenderClassification_v2.zip" -d /content/
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/39_0_3_20170119203757237.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/42_0_1_20170113184124287.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/57_0_3_20170119211315720.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/17_0_3_20161219224759672.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/34_0_3_20170119200820284.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/70_0_0_20170104213651117.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/53_0_4_20170109012743281.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/20_0_3_20170117151020539.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/34_0_1_20170116193916761.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/1_0_2_20161219210754437.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/50_0_3_20170119204714191.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/27_0_4_20170103235752276.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/23_0_3_20170119145303710.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/31_0_0_20170117153916924.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/46_0_4_20170120134419847.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/90_0_0_20170111211345356.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/45_0_3_20170119201309141.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/55_0_4_20170117204624770.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/27_0_0_20170116205304488.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/45_0_1_20170113190556169.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/50_0_1_20170113142149603.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/67_0_1_20170120224828928.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_2_20170104201313859.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/39_0_1_20170113174638723.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/50_0_0_20170117133129130.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/52_0_0_20170104212238236.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/40_0_4_20170104202246139.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/32_0_1_20170117010054839.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/69_0_3_20170112224615052.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/21_0_0_20170116215442146.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/1_0_0_20170109194232519.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/27_0_0_20170117134951867.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/34_0_1_20170112214929038.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/45_0_3_20170119162821908.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/10_0_4_20170103201924664.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/48_0_1_20170113184623503.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/35_0_4_20170117171324867.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/53_0_0_20170109012725288.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/15_0_0_20170104011728017.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/80_0_0_20170111210128898.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/58_0_0_20170117143055861.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/16_0_0_20170110232742700.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_4_20170117195554244.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/54_0_0_20170105173614957.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/24_0_3_20170117144123778.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/50_0_0_20170120133622629.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/38_0_0_20170104200835937.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/27_0_0_20170117020138207.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_0_20170117173437732.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/52_0_1_20170111204341094.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/42_0_0_20170117154747738.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/30_0_3_20170119195729476.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/22_0_2_20170104021125111.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/70_0_0_20170105173625820.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/55_0_1_20170117190614716.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/48_0_0_20170117170703274.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/9_0_0_20170110224736067.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_1_20170117021617321.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/59_0_0_20170104212234005.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/32_0_0_20170116235640652.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/32_0_1_20170113173619394.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/27_0_0_20170116215525646.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/58_0_3_20170119211701065.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/50_0_0_20170117135618315.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/21_0_0_20170104230103695.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/65_0_0_20170111201922080.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/31_0_0_20170116233154004.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/39_0_0_20170113134725338.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_2_20170116183023692.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/45_0_1_20170113142436445.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/24_0_4_20170117145214993.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/36_0_3_20170119183543230.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/51_0_2_20170116192859594.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/56_0_1_20170113184709263.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/25_0_2_20170116161438706.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/32_0_1_20170113001102379.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/30_0_1_20170116002938608.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/80_0_0_20170117175301125.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/53_0_2_20170112221930338.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/31_0_0_20170116003010656.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/18_0_1_20170116205256502.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/52_0_2_20170116183811379.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/55_0_3_20170119191938385.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/50_0_3_20170117181143891.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/74_0_2_20170105174417462.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/27_0_0_20170116205629794.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/25_0_0_20170117151831828.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/60_0_0_20170105173747117.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/27_0_2_20170116173713171.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/50_0_3_20170119203909752.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/22_0_2_20170116172210197.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/85_0_0_20170111210319130.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/54_0_2_20170111171747443.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/35_0_2_20170116173652735.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/33_0_1_20170113001600274.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/58_0_0_20170111195225616.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/50_0_0_20170104170550929.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/50_0_0_20170117160612319.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/2_0_3_20161219225707719.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/25_0_3_20170119144441117.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/1_0_0_20161219200250923.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/53_0_3_20170109132854337.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_3_20170119183349949.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/35_0_3_20170104201943761.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/24_0_3_20170119164713030.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/25_0_1_20170117195045410.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_3_20170119194502757.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/62_0_1_20170117154841208.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/61_0_2_20170112205453108.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/34_0_0_20170119171632720.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/65_0_0_20170117171038979.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/60_0_3_20170119205502432.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/38_0_3_20170119202715190.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/1_0_2_20161219203724580.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/27_0_1_20170116010418660.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/80_0_0_20170117175148148.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/30_0_0_20170117142917573.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/40_0_0_20170117170711073.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/18_0_0_20170110232049161.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_3_20170119192134681.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/32_0_1_20170117140227057.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/43_0_1_20170116205314288.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/50_0_2_20170117154145796.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/65_0_1_20170113184830231.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_1_20170117022132855.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/45_0_2_20170112215145176.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/89_0_3_20170105175600694.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/50_0_0_20170117190559865.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/67_0_0_20170117204838537.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_1_20170117020349205.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/59_0_3_20170104212824964.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/40_0_0_20170117120418754.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/36_0_0_20170105172557165.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/20_0_3_20170104225831145.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/36_0_0_20170104205158732.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/31_0_3_20170104231444482.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/59_0_0_20170117175959580.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/58_0_0_20170117193913647.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/85_0_2_20170112224212748.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/65_0_0_20170120225159632.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/7_0_0_20170110215335739.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/1_0_2_20161219155952157.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/58_0_0_20170117184403351.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/4_0_3_20170109131758363.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_4_20170117202313951.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/30_0_1_20170113141822196.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/50_0_0_20170120134101471.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/80_0_0_20170111205541652.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/90_0_0_20170111223757607.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/56_0_0_20170111203105369.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/24_0_4_20170115205946148.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/41_0_3_20170119162741678.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/37_0_3_20170119202310776.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/47_0_0_20170116204821089.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/61_0_0_20170117174636574.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/9_0_0_20170110225030430.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/43_0_0_20170117153817367.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/1_0_4_20161221195109583.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/54_0_0_20170104212538380.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/22_0_0_20170117171740692.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/32_0_4_20170104181254053.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/42_0_3_20170119171532128.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/33_0_0_20170117155210391.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/57_0_3_20170119180932004.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/1_0_4_20161221201458610.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/54_0_3_20170119210222264.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_1_20170113154949665.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/31_0_1_20170113175408636.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/32_0_1_20170116204750750.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/1_0_2_20161219155744942.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/18_0_3_20170104225809521.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/85_0_0_20170111205823547.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/15_0_1_20170113180633029.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/73_0_0_20170116221650300.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/62_0_0_20170111205219231.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/1_0_0_20170110213748813.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/34_0_3_20170119200635028.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/32_0_3_20170119200204548.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_1_20170104230506569.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/20_0_0_20170117134248038.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/29_0_0_20170102233617277.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/85_0_0_20170120221827893.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/35_0_0_20170117135217922.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/35_0_0_20170117182945085.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/32_0_4_20170104170633305.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/2_0_0_20161219154439741.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/45_0_2_20170116182728525.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/27_0_1_20170117012340251.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/1_0_2_20161219161822166.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/42_0_0_20170104181513925.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/62_0_1_20170113184846159.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/40_0_0_20170117134702038.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/40_0_0_20170116221901075.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/38_0_1_20170117185831737.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/65_0_0_20170120222816177.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_2_20170116163443678.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/7_0_0_20170110215648859.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/62_0_0_20170111210223707.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/37_0_2_20170116192041226.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/61_0_0_20170105173647189.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/23_0_3_20170119163856511.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/45_0_0_20170117185032873.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/44_0_1_20170117172143700.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_3_20170117152547043.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/34_0_0_20170104174028507.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/45_0_3_20170119195652068.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_0_20170117020857776.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/52_0_0_20170111181750501.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_1_20170115235544908.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/58_0_3_20170119211700248.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_2_20170119184053318.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/2_0_2_20161219190253835.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/45_0_1_20170113175345292.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/24_0_2_20170116173635907.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/25_0_3_20170119171615136.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/9_0_0_20170110220411186.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/63_0_0_20170105173717909.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/56_0_0_20170109012058588.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/1_0_0_20170109194042219.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_1_20170113151805863.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/24_0_2_20170116162912973.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/35_0_2_20170116172943457.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/13_0_0_20170110224751365.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/16_0_1_20170110231925176.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/25_0_0_20170117195027938.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/1_0_0_20170110213138878.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/40_0_3_20170119154448251.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/27_0_2_20170116184846062.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/50_0_4_20170117203237079.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/40_0_0_20170105172604533.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/27_0_0_20170103181014215.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_1_20170117200138532.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/42_0_2_20170104181453181.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_0_20170114024909834.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_0_20170113210126194.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/30_0_0_20170116221914812.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/35_0_2_20170116191142333.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/30_0_0_20170120220636164.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_3_20170120220130530.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_2_20170116175514457.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_3_20170119180851092.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/72_0_2_20170112224343210.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/58_0_0_20170111171747508.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/32_0_3_20170119200310531.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_3_20170117154449286.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/49_0_4_20170104205507484.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_3_20170119194806419.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/57_0_3_20170119181114683.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/58_0_1_20170113190411755.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/45_0_0_20170120222004116.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/24_0_0_20170117150336900.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/57_0_0_20170111203532804.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/23_0_3_20170119164205782.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/35_0_0_20170117120948071.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/35_0_3_20170119201304861.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/54_0_0_20170104212621156.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/45_0_3_20170104220631406.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/1_0_0_20170110212720644.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/16_0_0_20170110231909175.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/54_0_3_20170105173505798.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/34_0_0_20170105173453140.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/32_0_0_20170104202239802.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/25_0_0_20170120221436173.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_3_20170119181302068.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/44_0_3_20170119204716767.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/53_0_3_20170109142546975.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/54_0_0_20170117191341090.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/15_0_0_20170103200850696.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/82_0_0_20170111210449740.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/37_0_2_20170116184948230.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_3_20170119181350932.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_3_20170119194452931.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/72_0_1_20170111210712990.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/22_0_1_20170113150441654.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/45_0_0_20170117185004664.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/64_0_2_20170116193321184.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/4_0_3_20161220222705570.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/18_0_0_20170110231703804.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_1_20170117020634195.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/55_0_3_20170119201015604.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/54_0_0_20170104212522653.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/75_0_0_20170111205932368.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_0_20170113210126924.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/30_0_0_20170116224623527.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_0_20170117180236154.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/59_0_0_20170111203905144.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_2_20170116220607771.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/10_0_0_20170110220447314.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/9_0_0_20170110225344511.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/42_0_0_20170113184059799.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_1_20170113155103554.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/1_0_0_20170109191453449.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/76_0_2_20170112224304323.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/1_0_3_20161220220529033.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/24_0_0_20170116201407910.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/41_0_0_20170116202014245.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/27_0_2_20170116172522727.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/34_0_1_20170113155128778.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_0_20170119194754322.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/8_0_0_20170110220350538.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/25_0_3_20170119171508760.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/42_0_0_20170103181301064.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/36_0_1_20170113163308366.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_1_20170117003249556.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/34_0_1_20170116202042710.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/37_0_3_20170119152336983.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/35_0_0_20170117175619787.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/34_0_0_20170117134909111.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/62_0_0_20170111203239701.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/12_0_4_20170103200626630.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/24_0_1_20170114025920224.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/42_0_0_20170117120422779.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/25_0_1_20170116205335757.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/1_0_3_20161219230533840.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/45_0_0_20170117172231908.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_0_20170113210605342.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/45_0_1_20170117135648741.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/47_0_1_20170117172552003.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/39_0_2_20170117185137809.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/18_0_3_20170104225812688.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/29_0_3_20170119171739135.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/54_0_3_20170119210215919.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/35_0_0_20170104183524965.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/32_0_0_20170117154734499.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/24_0_1_20170120133915911.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/36_0_0_20170117183228479.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/25_0_0_20170114025954319.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/24_0_2_20170112192345078.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/37_0_0_20170104201816626.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/37_0_1_20170117164405007.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/36_0_0_20170117183317229.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/49_0_3_20170119201931356.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/24_0_2_20170116174324623.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/41_0_1_20170113151532863.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/10_0_0_20170110220255346.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/68_0_0_20170104184637742.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/23_0_2_20170116172805150.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/4_0_4_20161221202233593.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/75_0_1_20170113185328144.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/48_0_0_20170111200118842.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/22_0_3_20170119160342147.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/27_0_3_20170119193304964.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/54_0_0_20170117171400372.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/34_0_0_20170116030432644.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/78_0_2_20170112224416258.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/68_0_0_20170117172902192.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_1_20170113161434836.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/20_0_0_20170116205342932.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/68_0_2_20170112224243075.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/61_0_1_20170113175551340.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_0_20170113210126743.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/75_0_1_20170111205346848.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/32_0_1_20170113141942205.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/5_0_0_20170110213357051.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/60_0_3_20170119205726487.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_1_20170117154704178.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/68_0_0_20170117171408597.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/68_0_0_20170117171135900.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/30_0_2_20170104022129599.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/52_0_0_20170111204457405.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/1_0_2_20161219212700566.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/40_0_3_20170117154907806.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/68_0_3_20170119184302094.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/64_0_0_20170111222707336.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/37_0_1_20170117134417970.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/73_0_2_20170112224711435.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/36_0_0_20170103182808586.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/57_0_0_20170117172532619.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/42_0_0_20170104170602137.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/28_0_1_20170116192822460.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/24_0_3_20170119150342598.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/2_0_4_20170103204813658.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/46_0_0_20170117173358796.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/67_0_0_20170105172950852.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/48_0_2_20170104204459299.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/40_0_1_20170117135640172.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/48_0_0_20170104210544269.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/1_0_4_20161221202331737.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/16_0_0_20170110231811882.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/65_0_0_20170104213032541.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/1_0_4_20161221195047839.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/26_0_1_20170117200408766.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/25_0_3_20170117134150022.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/42_0_0_20170116224637121.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/49_0_1_20170117173446675.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/25_0_0_20170117142048826.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/4_0_0_20170110212621808.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Male/10_0_4_20170103212521420.jpg
#    creating: /content/Dataset_GenderClassification_v2/val/Female/
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/24_1_3_20170104222408639.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/29_1_1_20170116010429516.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/11_1_4_20170104005813063.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/29_1_2_20170116163350492.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/26_1_1_20170116184558816.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/2_1_2_20161219140706417.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/32_1_1_20170116000551316.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/16_1_0_20170109204155179.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/23_1_2_20170116173241444.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/35_1_1_20170112213036050.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/60_1_0_20170110152939871.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/29_1_1_20170114032143096.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/30_1_0_20170117203639423.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/44_1_3_20170119165505207.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/85_1_0_20170120221906501.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/43_1_1_20170116003503143.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/26_1_1_20170112224805692.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/2_1_2_20161219212055926.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/48_1_0_20170110154607979.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/49_1_0_20170104183921310.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/26_1_3_20170119181433587.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/3_1_0_20170109191748314.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/28_1_1_20170112204819027.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/25_1_3_20170119150412270.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/26_1_0_20170116184526152.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/28_1_1_20170112220128599.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/25_1_1_20170117154035392.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/64_1_0_20170110140833569.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/24_1_1_20170116224913775.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/35_1_3_20170104235136827.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/1_1_0_20170109194212472.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/93_1_0_20170110141221528.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/27_1_0_20170117120642103.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/27_1_2_20170116172637915.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/21_1_2_20170116171705211.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/95_1_0_20170110161313778.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/26_1_0_20170117003136628.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/24_1_2_20170116173412953.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/22_1_2_20161219153940196.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/18_1_0_20170105002457379.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/52_1_0_20170103163659575.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/25_1_1_20170114024700519.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/26_1_0_20170116170915992.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/32_1_2_20170103181041008.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/49_1_0_20170103180443960.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/1_1_2_20161219212720270.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/22_1_3_20170104232458346.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/31_1_1_20170117162539709.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/18_1_0_20170109213922168.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/60_1_0_20170110151441645.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/40_1_2_20170116161936667.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/27_1_0_20170104234600194.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/10_1_0_20170109203438428.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/18_1_0_20170117140340105.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/30_1_3_20170104232147226.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/34_1_0_20170116232936514.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/40_1_0_20170105172927477.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/26_1_2_20170116233134701.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/2_1_4_20161221202436617.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/7_1_0_20170109202403368.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/31_1_1_20170112235234538.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/35_1_1_20170117154228361.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/36_1_0_20170109141845861.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/1_1_2_20161219212416550.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/20_1_0_20170117192922563.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/74_1_1_20170120223559844.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/26_1_3_20170116180310868.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/65_1_1_20170112220241647.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/54_1_0_20170103183759282.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/1_1_0_20161219205534526.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/28_1_0_20170117204457679.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/12_1_0_20170103200944175.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/28_1_4_20170117202541845.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/24_1_0_20170117150731090.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/88_1_2_20170112003903252.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/36_1_0_20170103182902892.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/45_1_0_20170110141225753.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/35_1_0_20170116222143959.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/35_1_1_20170115235922203.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/21_1_3_20170104222121713.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/55_1_1_20170112213225871.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/25_1_2_20170116175317571.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/40_1_0_20170117174753056.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/25_1_0_20170117182558966.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/35_1_0_20170116235700676.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/29_1_1_20170112210246493.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/35_1_0_20170117121555358.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/29_1_0_20170104185616837.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/2_1_2_20161219162336446.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/28_1_2_20170105162338411.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/56_1_0_20170110141232209.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/61_1_0_20170113013135239.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/26_1_3_20170119180953860.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/2_1_4_20161221202644800.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/53_1_0_20170116201116129.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/4_1_2_20161219190751754.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/26_1_4_20170117154327501.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/33_1_3_20170104232231283.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/60_1_0_20170110152954671.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/85_1_0_20170110183536244.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/40_1_1_20170113005623327.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/65_1_0_20170110122548648.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/43_1_4_20170117204021688.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/45_1_3_20170119193000096.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/56_1_0_20170119202536518.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/1_1_4_20161221200049328.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/5_1_0_20170109193816878.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/26_1_0_20170112231759374.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/35_1_1_20170112215240346.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/65_1_0_20170110132559859.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/32_1_2_20170116190147549.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/36_1_1_20170117195448051.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/31_1_1_20170116233436288.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/4_1_4_20161223225928843.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/24_1_0_20170117194857869.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/70_1_0_20170120222024102.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/25_1_1_20170113180645637.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/8_1_1_20170117135414790.jpg
#   inflating: /content/Dataset_GenderClassification_v2/val/Female/24_1_4_20170103233659572.jpg
# ...
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/32_1_0_20170120220940628.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/2_1_4_20161221193638214.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/35_1_1_20170113012452639.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/26_1_2_20170116184247227.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/9_1_0_20170109202819671.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/26_1_1_20170112210240181.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/25_1_0_20170104023032454.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/26_1_3_20170119180600308.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/8_1_2_20170116194013325.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/3_1_2_20161219204608087.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/42_1_1_20170113013004135.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/26_1_1_20170112213221119.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/21_1_1_20170116215704702.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/4_1_0_20170109193102653.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/30_1_2_20170116174642075.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/5_1_2_20161219194328354.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/3_1_0_20161220220147617.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/28_1_4_20170117170432153.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/2_1_3_20161219224614064.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/17_1_0_20170109201558943.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/25_1_3_20170117152028652.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/8_1_0_20170109205022859.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/4_1_2_20161219160945062.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/31_1_3_20170104223530512.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/26_1_0_20170117174547382.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/14_1_3_20170104013523266.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/90_1_0_20170120221911645.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/8_1_0_20170109205256828.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/38_1_1_20170112205041100.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/4_1_2_20161219154653077.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/51_1_0_20170110160643172.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/36_1_0_20170117135900421.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/53_1_1_20170113013025665.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/51_1_0_20170110123530286.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/26_1_3_20170104223003860.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/21_1_4_20170103233924667.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/24_1_2_20170116174621192.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/76_1_2_20170110143551965.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/73_1_0_20170110140417960.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/22_1_4_20170103224958800.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/68_1_0_20170110143529881.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/29_1_2_20170116172543850.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/23_1_1_20170117194137453.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/1_1_1_20170109190848182.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/19_1_3_20170119145633822.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/14_1_0_20170109213548658.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/1_1_0_20170109193014933.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/25_1_2_20170116165425465.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/21_1_3_20170104222056815.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/18_1_0_20170109212914272.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/32_1_1_20170116232547353.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/31_1_0_20170117131145761.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/48_1_1_20170117131013277.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/88_1_3_20170110182157752.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/17_1_3_20170104221822223.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/27_1_0_20170119155531065.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/31_1_2_20170116170736523.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/29_1_4_20170117202752934.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/38_1_0_20170117121922741.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/6_1_0_20170109193725492.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/46_1_1_20170113184212578.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/4_1_2_20161219141110241.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/80_1_0_20170110182353061.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/24_1_1_20170112234348991.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/16_1_3_20170104222208647.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/26_1_4_20170117154047070.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/78_1_0_20170120224727472.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/49_1_0_20170109220434368.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/2_1_4_20170103213208251.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/38_1_1_20170116154709016.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/34_1_3_20170109141950796.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/34_1_3_20170105001226421.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/5_1_2_20161219154637884.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/14_1_1_20170112230439326.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/24_1_2_20170116173430041.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/25_1_3_20170117143802585.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/12_1_2_20170104012405785.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/38_1_4_20170117203646323.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/4_1_0_20170104005821656.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/34_1_3_20170119200853821.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/27_1_2_20170116162544980.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/20_1_3_20170117141155272.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/18_1_1_20170116211857195.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/72_1_0_20170110131657098.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/29_1_1_20170116000522670.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/27_1_1_20170117005946474.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/27_1_1_20170117013845090.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/38_1_4_20170117203712774.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/30_1_1_20170114033246944.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/25_1_2_20170116175126325.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/26_1_0_20170117003252979.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/45_1_0_20170109221119437.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/30_1_0_20170117091710631.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/35_1_0_20170117135330351.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/25_1_3_20170119154344723.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/3_1_2_20161219212214190.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/45_1_0_20170117175418025.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/27_1_3_20170109132029072.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/24_1_2_20170116174534993.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/1_1_0_20170109191212799.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/24_1_2_20170116173716204.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/24_1_0_20170116222429652.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/78_1_1_20170113011857601.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/25_1_3_20170117151149187.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/24_1_4_20170104005830151.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/31_1_0_20170117133158992.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/28_1_1_20170117165607911.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/1_1_3_20161220143241765.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/24_1_2_20170116165534569.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/26_1_1_20170116024218334.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/32_1_0_20170117134816396.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/1_1_3_20161220220548777.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/7_1_3_20161219225222280.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/29_1_0_20170103181425489.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/45_1_1_20170116160543061.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/25_1_3_20170119171917192.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/48_1_0_20170109135746831.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/1_1_3_20161220143350174.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/16_1_4_20170103233406635.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/13_1_0_20170109205106776.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/37_1_0_20170119202548638.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/100_1_0_20170112215032192.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/4_1_0_20170110213431280.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/26_1_1_20170117200332549.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/85_1_2_20170110182342530.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/23_1_1_20170114030249007.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/23_1_3_20170104231559289.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/26_1_1_20170116011427995.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/36_1_0_20170113000608163.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/26_1_0_20170117175317465.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/82_1_1_20170110154342872.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/62_1_1_20170113001915427.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/20_1_0_20170109214618635.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/22_1_2_20170116172137259.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/27_1_4_20170103223631359.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/4_1_0_20170109202352144.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/35_1_0_20170117190625474.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/25_1_2_20170104015640427.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/85_1_0_20170110181632797.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/24_1_0_20170116205900085.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/3_1_2_20161219160308941.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/23_1_3_20170119164537949.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/28_1_2_20170116164237338.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/40_1_1_20170113000039241.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/24_1_2_20170116172622785.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/54_1_0_20170117171555172.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/57_1_3_20170104234847956.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/30_1_3_20170104235542236.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/35_1_0_20170117121936119.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/1_1_1_20170109191256746.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/39_1_3_20170104232838176.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/31_1_1_20170116173451354.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/26_1_0_20170103181123449.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/18_1_1_20170114030253404.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/28_1_3_20170104223337415.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/37_1_3_20170109141945326.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/25_1_3_20170104222454999.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/26_1_2_20170116180003876.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/24_1_2_20170116174528024.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/3_1_2_20161219141855897.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/27_1_2_20170104021735596.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/37_1_0_20170105172735429.jpg
#   inflating: /content/Dataset_GenderClassification_v2/train/Female/28_1_3_20170104223537760.jpg

# %%
ROOT = "/content/Dataset_GenderClassification_v2"   # <- CAMBIA: contiene train/ val/ test/

# --- Modelo: "EfficientNetB4" o "EfficientNetB5" ---
MODEL_FAMILY = "EfficientNetB4"              # "EfficientNetB5" si prefieres

# --- Tamaño de imagen según el modelo ---
IMG_SIZE = (380, 380) if MODEL_FAMILY == "EfficientNetB4" else (456, 456)

# --- Entrenamiento ---
BATCH = 8                 # B4: 8–16; B5: 4–8 (según VRAM)
SEED = 42
EPOCHS_HEAD = 10          # etapa 1 (backbone congelado)
EPOCHS_FT   = 20          # etapa 2 (fine-tuning)
UNFREEZE_FROM = -60       # desbloquear últimas N capas del backbone

LR_HEAD = 1e-3
LR_FT   = 1e-4
MIXED_PRECISION = True    # activa si tu GPU lo soporta

# %%
# --- Cache en disco (opcional) ---
USE_DISK_CACHE = False
CACHE_DIR = "/tmp/keras_cache_efficientnet"

# %%
# --- Directorio de salida ---
OUTDIR = "./export_efficientnet_b4_b5"
os.makedirs(OUTDIR, exist_ok=True)

print("ROOT:", ROOT, "| MODEL:", MODEL_FAMILY, "| IMG_SIZE:", IMG_SIZE, "| BATCH:", BATCH)
# Out:
# ROOT: /content/Dataset_GenderClassification_v2 | MODEL: EfficientNetB4 | IMG_SIZE: (380, 380) | BATCH: 8

# %%
# Limpieza y GPU
tf.keras.backend.clear_session(); gc.collect()
gpus = tf.config.list_physical_devices('GPU')
for g in gpus:
    try: tf.config.experimental.set_memory_growth(g, True)
    except: pass

if MIXED_PRECISION:
    try:
        from tensorflow.keras import mixed_precision
        mixed_precision.set_global_policy("mixed_float16")
        print("[i] Mixed precision ACTIVADA")
    except Exception as e:
        print("[!] Mixed precision no disponible:", e)
# Out:
# [i] Mixed precision ACTIVADA

# %%
# ================== Carga de Datasets ==================
train_dir = os.path.join(ROOT, "train")
val_dir   = os.path.join(ROOT, "val")
test_dir  = os.path.join(ROOT, "test")

# 1) Carga "raw" para conservar class_names antes de envolver
raw_train_ds = keras.utils.image_dataset_from_directory(
    train_dir, image_size=IMG_SIZE, batch_size=BATCH, seed=SEED, shuffle=True
)
raw_val_ds = keras.utils.image_dataset_from_directory(
    val_dir, image_size=IMG_SIZE, batch_size=BATCH, seed=SEED, shuffle=False
)
raw_test_ds = keras.utils.image_dataset_from_directory(
    test_dir, image_size=IMG_SIZE, batch_size=BATCH, seed=SEED, shuffle=False
)

# 2) class_names / num_classes
class_names = raw_train_ds.class_names
num_classes = len(class_names)
print("[i] Clases:", class_names)

# 3) Envolver (sin cache en RAM). Puedes activar cache en DISCO si quieres
AUTOTUNE = tf.data.AUTOTUNE
if USE_DISK_CACHE:
    os.makedirs(CACHE_DIR, exist_ok=True)
    train_cache_file = os.path.join(CACHE_DIR, "train.cache")
    val_cache_file   = os.path.join(CACHE_DIR, "val.cache")
    test_cache_file  = os.path.join(CACHE_DIR, "test.cache")
else:
    train_cache_file = val_cache_file = test_cache_file = None

def cfg(ds, shuffle=False, cache_file=None):
    ds = ds.map(lambda x, y: (x, y), num_parallel_calls=2)  # limita paralelismo (RAM)
    if cache_file:
        ds = ds.cache(cache_file)  # cache en DISCO (opcional)
    if shuffle:
        ds = ds.shuffle(BATCH * 8, seed=SEED)
    return ds.prefetch(AUTOTUNE)

train_ds = cfg(raw_train_ds, shuffle=True,  cache_file=train_cache_file)
val_ds   = cfg(raw_val_ds,   shuffle=False, cache_file=val_cache_file)
test_ds  = cfg(raw_test_ds,  shuffle=False, cache_file=test_cache_file)
# Out:
# Found 4032 files belonging to 2 classes.
# Found 1152 files belonging to 2 classes.
# Found 576 files belonging to 2 classes.
# [i] Clases: ['Female', 'Male']

# %%
# ================== Class Weights (opcional) ==================
def count_images_by_class(folder, class_names):
    counts = {}
    for c in class_names:
        p = os.path.join(folder, c)
        n = sum(len(files) for _, _, files in os.walk(p)) if os.path.isdir(p) else 0
        counts[c] = n
    return counts

train_counts = count_images_by_class(train_dir, class_names)
total = sum(train_counts.values())
class_weight = {}
for i, c in enumerate(class_names):
    n = train_counts[c]
    class_weight[i] = (total / (num_classes * n)) if n > 0 else 0.0

print("[i] Train counts:", train_counts)
print("[i] class_weight:", class_weight)
# Si quieres desactivar: pon class_weight=None en model.fit()
# Out:
# [i] Train counts: {'Female': 2016, 'Male': 2016}
# [i] class_weight: {0: 1.0, 1: 1.0}

# %%
# ================== Modelo (EfficientNet B4/B5) ==================
from tensorflow.keras.applications.efficientnet import preprocess_input as eff_preprocess

base_cls = getattr(keras.applications, MODEL_FAMILY)  # EfficientNetB4 o EfficientNetB5

# Augmentations (NO usar Rescaling cuando empleas preprocess_input de EfficientNet)
data_aug = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
], name="data_augmentation")

def build_model(num_classes, img_size):
    base = base_cls(include_top=False, weights="imagenet", input_shape=img_size + (3,))
    base.trainable = False  # Etapa 1: congelado

    inputs = keras.Input(shape=img_size + (3,))
    x = layers.Lambda(eff_preprocess, name="preprocess")(inputs)  # CLAVE
    x = data_aug(x)
    x = base(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    # Si hay mixed precision, fuerza salida en float32
    dtype = "float32" if tf.keras.mixed_precision.global_policy().name == "mixed_float16" else None
    outputs = layers.Dense(num_classes, activation="softmax", dtype=dtype)(x)
    model = keras.Model(inputs, outputs, name=f"{MODEL_FAMILY}_clf")
    return model, base

model, base_model = build_model(num_classes, IMG_SIZE)
model.summary(line_length=120)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71686520/71686520 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "EfficientNetB4_clf"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━
# ┃ Layer (type)                                        ┃ Output Shape                           ┃               Para
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━
# │ input_layer_1 (InputLayer)                          │ (None, 380, 380, 3)                    │
# ├─────────────────────────────────────────────────────┼────────────────────────────────────────┼───────────────────
# │ preprocess (Lambda)                                 │ (None, 380, 380, 3)                    │
# ├─────────────────────────────────────────────────────┼────────────────────────────────────────┼───────────────────
# │ data_augmentation (Sequential)                      │ (None, 380, 380, 3)                    │
# ├─────────────────────────────────────────────────────┼────────────────────────────────────────┼───────────────────
# │ efficientnetb4 (Functional)                         │ (None, 12, 12, 1792)                   │            17,673,
# ├─────────────────────────────────────────────────────┼────────────────────────────────────────┼───────────────────
# │ global_average_pooling2d (GlobalAveragePooling2D)   │ (None, 1792)                           │
# ├─────────────────────────────────────────────────────┼────────────────────────────────────────┼───────────────────
# │ dropout (Dropout)                                   │ (None, 1792)                           │
# ├─────────────────────────────────────────────────────┼────────────────────────────────────────┼───────────────────
# │ dense (Dense)                                       │ (None, 2)                              │                 3,
# └─────────────────────────────────────────────────────┴────────────────────────────────────────┴───────────────────
#  Total params: 17,677,409 (67.43 MB)
#  Trainable params: 3,586 (14.01 KB)
#  Non-trainable params: 17,673,823 (67.42 MB)

# %%
# ================== Callbacks + Etapa 1 ==================
ckpt_dir = os.path.join(OUTDIR, "ckpts"); os.makedirs(ckpt_dir, exist_ok=True)

cbs_head = [
    keras.callbacks.ModelCheckpoint(
        filepath=os.path.join(ckpt_dir, "genero_head.keras"),
        monitor="val_accuracy", save_best_only=True
    ),
    keras.callbacks.EarlyStopping(
        monitor="val_accuracy", patience=5, restore_best_weights=True
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=2, min_lr=1e-6
    ),
]

model.compile(optimizer=keras.optimizers.Adam(LR_HEAD),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

history_head = model.fit(
    train_ds, validation_data=val_ds, epochs=EPOCHS_HEAD,
    callbacks=cbs_head, class_weight=class_weight
)
# Out:
# Epoch 1/10
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 141s 181ms/step - accuracy: 0.8142 - loss: 0.3943 - val_accuracy: 0.8733 - val_loss: 0.2943 - learning_rate: 0.0010
# Epoch 2/10
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 107s 162ms/step - accuracy: 0.8844 - loss: 0.2811 - val_accuracy: 0.8793 - val_loss: 0.2752 - learning_rate: 0.0010
# Epoch 3/10
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 147s 171ms/step - accuracy: 0.8883 - loss: 0.2603 - val_accuracy: 0.8802 - val_loss: 0.2757 - learning_rate: 0.0010
# Epoch 4/10
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 87s 170ms/step - accuracy: 0.8909 - loss: 0.2623 - val_accuracy: 0.8872 - val_loss: 0.2676 - learning_rate: 0.0010
# Epoch 5/10
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 143s 171ms/step - accuracy: 0.8875 - loss: 0.2614 - val_accuracy: 0.8898 - val_loss: 0.2664 - learning_rate: 0.0010
# Epoch 6/10
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 81s 158ms/step - accuracy: 0.8985 - loss: 0.2609 - val_accuracy: 0.8854 - val_loss: 0.2639 - learning_rate: 0.0010
# Epoch 7/10
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 85s 167ms/step - accuracy: 0.8976 - loss: 0.2511 - val_accuracy: 0.8863 - val_loss: 0.2638 - learning_rate: 0.0010
# Epoch 8/10
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 82s 158ms/step - accuracy: 0.9030 - loss: 0.2455 - val_accuracy: 0.8845 - val_loss: 0.2541 - learning_rate: 0.0010
# Epoch 9/10
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 86s 167ms/step - accuracy: 0.9070 - loss: 0.2276 - val_accuracy: 0.8880 - val_loss: 0.2727 - learning_rate: 0.0010
# Epoch 10/10
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 86s 168ms/step - accuracy: 0.8862 - loss: 0.2614 - val_accuracy: 0.8863 - val_loss: 0.2643 - learning_rate: 0.0010

# %% [markdown]
# (no hacer etapa 2 aun)

# %%
# ================== Etapa 2: Fine-tuning ==================
base_model.trainable = True
for layer in base_model.layers[:UNFREEZE_FROM]:
    layer.trainable = False

model.compile(optimizer=keras.optimizers.Adam(LR_FT),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

cbs_ft = [
    keras.callbacks.ModelCheckpoint(
        filepath=os.path.join(ckpt_dir, "best_finetuned.keras"),
        monitor="val_accuracy", save_best_only=True
    ),
    keras.callbacks.EarlyStopping(
        monitor="val_accuracy", patience=6, restore_best_weights=True
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=2, min_lr=1e-6
    ),
]

history_ft = model.fit(
    train_ds, validation_data=val_ds, epochs=EPOCHS_FT,
    callbacks=cbs_ft, class_weight=class_weight
)

# %% [markdown]
# TEST

# %%
# ================== Evaluación ==================
test_loss, test_acc = model.evaluate(test_ds, verbose=1)
print(f"[i] Test accuracy: {test_acc:.4f}  |  loss: {test_loss:.4f}")
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.8531 - loss: 0.3180
# [i] Test accuracy: 0.8802  |  loss: 0.2911

# %%
# ================== Guardado (Keras + metadatos) ==================
final_model_path = os.path.join(OUTDIR, "model.keras")
model.save(final_model_path)
print(f"[i] Modelo guardado en: {final_model_path}")

with open(os.path.join(OUTDIR, "class_names.json"), "w") as f:
    json.dump(class_names, f, indent=2)

with open(os.path.join(OUTDIR, "metrics.json"), "w") as f:
    json.dump({
        "test_loss": float(test_loss),
        "test_accuracy": float(test_acc),
        "img_size": IMG_SIZE,
        "model_family": MODEL_FAMILY,
        "train_counts": train_counts
    }, f, indent=2)

print("[i] Artefactos listos en", OUTDIR)
# Out:
# [i] Modelo guardado en: ./export_efficientnet_b4_b5/model.keras
# [i] Artefactos listos en ./export_efficientnet_b4_b5

# %% [markdown]
# GUARDAR MODELO PRODUCIDO EN LA PRIMERA ETAPA:

# %%
# ===== Guardado del modelo de ETAPA 1 (solo cabeza) con nombre informativo =====
import os, datetime, numpy as np

# mejor val_accuracy de la etapa 1
best_val_acc_head = float(np.max(history_head.history.get("val_accuracy", [0.0])))

stamp = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
fname_head = f"{MODEL_FAMILY}_HEAD_{IMG_SIZE[0]}x{IMG_SIZE[1]}_valAcc{best_val_acc_head:.3f}_{stamp}.keras"

os.makedirs(OUTDIR, exist_ok=True)
path_head = os.path.join(OUTDIR, fname_head)

# OJO: aquí el modelo en memoria ya tiene los "mejores pesos" (early stopping con restore_best_weights=True)
model.save(path_head)
print(f"[i] Modelo ETAPA 1 guardado en:\n  {path_head}")
# Out:
# [i] Modelo ETAPA 1 guardado en:
#   ./export_efficientnet_b4_b5/EfficientNetB4_HEAD_380x380_valAcc0.890_20250901-024952.keras

# %% [markdown]
# INFERENCIAS:

# %%
# ===== Inferencia por rutas (archivos sueltos) =====
import os, glob
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

def load_image_for_model(path, img_size):
    img = Image.open(path).convert("RGB").resize(img_size)
    arr = np.array(img, dtype=np.float32)   # el modelo aplica preprocess internamente
    arr = np.expand_dims(arr, axis=0)       # [1,H,W,3]
    return img, arr

# Ejemplos: toma 1 imagen de cada clase (si existe)
sample_paths = []
for cls in class_names:
    pattern = os.path.join(test_dir, cls, "*")
    files = glob.glob(pattern)
    if files:
        sample_paths.append(files[0])
    if len(sample_paths) >= 9:   # limita a 9 para el demo
        break

plt.figure(figsize=(12, 12))
for i, p in enumerate(sample_paths[:9]):
    img, arr = load_image_for_model(p, IMG_SIZE)
    prob = model.predict(arr, verbose=0)[0]
    pred_idx = int(np.argmax(prob))
    pred_cls = class_names[pred_idx]
    conf = float(np.max(prob))

    ax = plt.subplot(2, 5, i+1)
    plt.imshow(img)
    ax.set_title(f"{os.path.basename(os.path.dirname(p))}\nPred: {pred_cls} ({conf:.2f})", fontsize=10)
    ax.axis("off")

plt.suptitle("Inferencia por rutas de imagen", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# INFERENCIA A UN GRUPO DE IMAGENES

# %%
# --- Cargar modelo .keras que contiene Lambda(preprocess_input) en tf.keras ---
import os, json, tensorflow as tf
from tensorflow import keras

MODEL_PATH = "/content/export_efficientnet_b4_b5/ckpts/genero_head.keras"   # <-- ajusta
CLASS_NAMES_PATH = "/content/export_efficientnet_b4_b5/class_names.json"  # <-- ajusta

# 1) Trae la función oficial de EfficientNet y REGÍSTRALA para deserializar Lambdas
from tensorflow.keras.applications.efficientnet import preprocess_input as eff_preprocess
from tensorflow.keras.utils import register_keras_serializable, get_custom_objects

@register_keras_serializable(package="preproc", name="preprocess_input")
def _registered_preprocess(x):
    return eff_preprocess(x)

# Por si la Lambda fue nombrada "preprocess"
get_custom_objects().update({
    "preprocess_input": _registered_preprocess,
    "preprocess": _registered_preprocess,
})

# 2) Carga el modelo (en tf.keras NO uses safe_mode)
model = keras.models.load_model(
    MODEL_PATH,
    custom_objects={
        "preprocess_input": _registered_preprocess,
        "preprocess": _registered_preprocess
    }
)
print("Modelo cargado ✅")

# 3) Tamaño esperado por el modelo
in_shape = model.inputs[0].shape
IMG_SIZE = (int(in_shape[1]), int(in_shape[2]))
print("IMG_SIZE inferida del modelo:", IMG_SIZE)

# 4) Clases (si existe el JSON)
if os.path.exists(CLASS_NAMES_PATH):
    with open(CLASS_NAMES_PATH) as f:
        class_names = json.load(f)
    print("Clases:", class_names)
else:
    class_names = None
    print("No se encontró class_names.json (se mostrarán índices).")

print("TF version:", tf.__version__, "| Keras backend:", keras.__version__)
# Out:
# Modelo cargado ✅
# IMG_SIZE inferida del modelo: (380, 380)
# Clases: ['Female', 'Male']
# TF version: 2.19.0 | Keras backend: 3.10.0

# %%
# Carga de labels (rangos de edad) con fallback
import os, json
from tensorflow import keras

# Asegúrate de que la ruta exista (ajústala a tu carpeta real)
CLASS_NAMES_PATH = "/content/export_efficientnet_b4_b5/class_names.json"

# Fallback por si no existe el JSON (ajusta el orden si el tuyo es distinto)
FALLBACK_LABELS = ["0_9","10_19","20_29","30_39","40_49","50_59","60_69","70_79","80_plus"]

# 1) intentar leer del JSON
if os.path.exists(CLASS_NAMES_PATH):
    with open(CLASS_NAMES_PATH) as f:
        class_names = json.load(f)
else:
    class_names = FALLBACK_LABELS

# 2) sanity: si no coincide con el # de salidas del modelo, usa fallback recortado
num_out = model.output_shape[-1]
if len(class_names) != num_out:
    print(f"[!] class_names tenía {len(class_names)} entradas; el modelo tiene {num_out}. Se usará fallback.")
    class_names = FALLBACK_LABELS[:num_out]

print("[i] class_names =", class_names)
# Out:
# [i] class_names = ['Female', 'Male']

# %% [markdown]
# DESCARGAR EL MODELO

# %%
# Descarga tu modelo y metadatos desde Colab
import os, shutil
from google.colab import files

# Ajusta si guardaste en otra ruta
OUTDIR = "/content/export_efficientnet_b4_b5/ckpts"   # carpeta donde guardaste model.keras, class_names.json, metrics.json
MODEL_PATH = os.path.join(OUTDIR, "genero_head.keras")

# Opción A: descargar SOLO el .keras
if os.path.exists(MODEL_PATH):
    print("Descargando:", MODEL_PATH)
    files.download(MODEL_PATH)
else:
    print("No se encontró:", MODEL_PATH)

# %%
# --- Inferencia en carpeta + visualización (Colab) ---
import os, glob, math
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# === CONFIG ===
FOLDER = "/content/drive/MyDrive/imagenes_de_prueba"  # <-- ajusta
RECURSIVE = True
BATCH_INFER = 16      # baja a 8/4 si hace falta
MAX_PER_PAGE = 16     # 4x4
MAX_PAGES = 10

def list_images(folder, recursive=True):
    exts = ["*.jpg","*.jpeg","*.png","*.bmp","*.webp"]
    files = []
    if recursive:
        for ext in exts:
            files += glob.glob(os.path.join(folder, "**", ext), recursive=True)
    else:
        for ext in exts:
            files += glob.glob(os.path.join(folder, ext))
    return sorted(files)

def load_img_arr(path, img_size):
    img = Image.open(path).convert("RGB").resize(img_size)
    arr = np.array(img, dtype=np.float32)   # el modelo aplica preprocess internamente
    return img, arr

def batched(iterable, n):
    for i in range(0, len(iterable), n):
        yield iterable[i:i+n]

img_paths = list_images(FOLDER, RECURSIVE)
print(f"Encontradas {len(img_paths)} imágenes en:\n  {FOLDER}")
if not img_paths:
    raise SystemExit("No se encontraron imágenes; revisa FOLDER.")

# --- Inferencia por lotes ---
all_preds, all_confs, all_true = [], [], []
for batch_paths in batched(img_paths, BATCH_INFER):
    batch_imgs = []
    for p in batch_paths:
        _, arr = load_img_arr(p, IMG_SIZE)
        batch_imgs.append(arr)
    batch_x = np.stack(batch_imgs, axis=0)                # [N,H,W,3] float32
    probs = model.predict(batch_x, verbose=0)             # modelo ya contiene preprocess
    preds = np.argmax(probs, axis=1)
    confs = np.max(probs, axis=1)

    all_preds.extend(preds.tolist())
    all_confs.extend(confs.tolist())

    # Etiqueta "real" si la carpeta padre coincide con una clase conocida
    for p in batch_paths:
        parent = os.path.basename(os.path.dirname(p))
        all_true.append(parent if (class_names and parent in class_names) else None)

# --- Visualización paginada ---
def show_pages(paths, preds, confs, ytrue, class_names, img_size, max_per_page=16, max_pages=10):
    pages = min(math.ceil(len(paths)/max_per_page), max_pages)
    for pg in range(pages):
        start = pg * max_per_page
        end   = min((pg+1) * max_per_page, len(paths))
        n     = end - start
        cols  = 4
        rows  = math.ceil(n/cols)
        plt.figure(figsize=(4*cols, 4*rows))
        for i, idx in enumerate(range(start, end), start=1):
            p = paths[idx]
            pred_idx = int(preds[idx])
            conf = confs[idx]
            pred_label = class_names[pred_idx]  # <-- usa el rango de edad
            true_cls = ytrue[idx]

            img = Image.open(p).convert("RGB").resize(img_size)
            ax = plt.subplot(rows, cols, i)
            ax.imshow(img)
            title = f"Pred: {pred_label} ({conf:.2f})"
            if true_cls is not None:
                title = f"GT: {true_cls}\n" + title
            ax.set_title(title, fontsize=10)
            ax.axis("off")
        plt.suptitle(f"Página {pg+1}/{pages} — {os.path.basename(FOLDER)}", fontsize=14)
        plt.tight_layout()
        plt.show()

show_pages(img_paths, all_preds, all_confs, all_true, class_names, IMG_SIZE,
           max_per_page=MAX_PER_PAGE, max_pages=MAX_PAGES)
# Out:
# Encontradas 4 imágenes en:
#   /content/drive/MyDrive/imagenes_de_prueba

# %%
# Opción B: descargar TODO el directorio como ZIP (modelo + class_names.json + metrics.json + ckpts/)
# !zip -r /content/export_efficientnet_b4_b5.zip /content/export_efficientnet_b4_b5
